# %%
from yfapi import YahooFinanceAPI, Interval
import datetime

# instantiate the API and set the interval to weekly data
dh = YahooFinanceAPI(Interval.DAILY)
now = datetime.datetime(2022, 11, 26)
then = datetime.datetime(2022, 11, 19)

# returns dataframe holding the historical data
df = dh.get_ticker_data("BTC-USD", then, now)

# %%
df.head(10)
# Out:
#         Date          Open          High           Low         Close  \
# 0 2022-11-19  16696.220703  16797.876953  16570.410156  16711.546875
# 1 2022-11-20  16712.919922  16746.779297  16248.692383  16291.832031
# 2 2022-11-21  16291.223633  16291.223633  15599.046875  15787.284180
# 3 2022-11-22  15782.300781  16253.047852  15656.606445  16189.769531
# 4 2022-11-23  16195.588867  16638.193359  16170.502930  16610.707031
# 5 2022-11-24  16611.636719  16771.474609  16501.767578  16604.464844
# 6 2022-11-25  16602.269531  16603.316406  16388.404297  16521.841797
# 7 2022-11-26  16521.576172  16666.863281  16416.228516  16464.281250
#
#       Adj Close       Volume
# 0  16711.546875  16106223492
# 1  16291.832031  21313378652
# 2  15787.284180  37429485518
# 3  16189.769531  30726828760
# 4  16610.707031  32958875628
# 5  16604.464844  26129037414
# 6  16521.841797  18678255976
# 7  16464.281250  18000008764

# %%
now = datetime.datetime(2022, 11, 25)
then = datetime.datetime(2017, 1, 1)
df = dh.get_ticker_data("BTC-USD", then, now)

# %%
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 1    2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2    2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 3    2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 4    2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...         ...           ...           ...           ...           ...
# 2150 2022-11-21  16291.223633  16291.223633  15599.046875  15787.284180
# 2151 2022-11-22  15782.300781  16253.047852  15656.606445  16189.769531
# 2152 2022-11-23  16195.588867  16638.193359  16170.502930  16610.707031
# 2153 2022-11-24  16611.636719  16771.474609  16501.767578  16604.464844
# 2154 2022-11-25  16602.269531  16603.316406  16388.404297  16521.841797
#
#          Adj Close       Volume
# 0       998.325012    147775008
# 1      1021.750000    222184992
# ...

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
from utils import *

# %%
df = preprocess_data(df)

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...                  ...           ...           ...           ...
# 2022-11-21  16291.223633  16291.223633  15599.046875  15787.284180
# 2022-11-22  15782.300781  16253.047852  15656.606445  16189.769531
# 2022-11-23  16195.588867  16638.193359  16170.502930  16610.707031
# 2022-11-24  16611.636719  16771.474609  16501.767578  16604.464844
# 2022-11-25  16602.269531  16603.316406  16388.404297  16521.841797
#
#                  Volume
# Date
# 2017-01-01    147775008
# 2017-01-02    222184992
# 2017-01-03    185168000
# 2017-01-04    344945984
# ...

# %%
df.index[0]
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
import pandas as pd

# %%
df.to_csv('dataset/test.csv')

# %%
now = datetime.datetime(2022, 11, 25)
then = datetime.datetime(2020, 1, 1)
df2 = dh.get_ticker_data("BTC-USD", then, now)

# %%
df2 = preprocess_data(df2)

# %%
df2.to_csv('dataset/test2.csv')
